# %% [markdown]
# <div align="center">
#   <h1> 1 - Getting Data - Eminem Lyrics</h1> <a name="0-bullet"></a>
# </div>

# %% [markdown]
# - [1. Setup](#1-bullet)
#     * [1.1 Set the working directory](#11-bullet)
# - [2. Collect the data](#2-bullet)
#     * [2.1 Connect to the Genius API](#21-bullet)
#     * [2.2 Get the lyrics](#22-bullet)
# - [3. Save/load the Genius Artist object](#3-bullet)
#     * [3.1 Save the object](#31-bullet)
#     * [3.2 Load the object](#32-bullet)
# - [4. Convert to a Pandas DataFrame object](#4-bullet)
#     * [4.1 Store the DataFrame object](#41-bullet)
#
# > References:
# > * [LyricsGenius: a Python client for the Genius.com API](https://lyricsgenius.readthedocs.io/en/master/index.html)

# %% [markdown]
# ---

# %% [markdown]
# You may have to install:
# >`pip install lyricsgenius`

# %%
import os
import json
import pickle

import numpy as np
import pandas as pd
import lyricsgenius as genius

from tqdm import tqdm

# %% [markdown]
# ---

# %% [markdown]
# # 1. Setup <a name="1-bullet"></a> <a href="#0-bullet"> <sup><sup><sup>^</sup></sup></sup></a>

# %% [markdown]
# ## 1.1 Set the working directory <a name="11-bullet"></a>

# %%
ROOT_DIR = "./eminem-lyrics-generator/notebooks/" 
IN_GOOGLE_COLAB = True

if IN_GOOGLE_COLAB:
    # mount google drive
    from google.colab import drive
    drive.mount('/content/gdrive')

    # change the current working directory
    # %cd gdrive/'My Drive'

    # create a root directory if there's none
    if not os.path.isdir(ROOT_DIR):
        # %mkdir $ROOT_DIR

    # change the current working directory
    # %cd $ROOT_DIR
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive
# /content/gdrive/My Drive/eminem-lyrics-generator/notebooks

# %%
# specifies paths to all files in the project
SETTINGS_FILE_PATH = os.path.join(os.path.abspath(".."), 'SETTINGS.json')
settings = json.load(open(SETTINGS_FILE_PATH))

# %% [markdown]
# # 2. Collect the data <a name="2-bullet"></a> <a href="#0-bullet"> <sup><sup><sup>^</sup></sup></sup></a>

# %% [markdown]
# ## 2.1 Connect to the Genius API <a name="21-bullet"></a>

# %%
# assign Genius.com credentials
GENIUSCREDS = "<YOUR-GENIUS-CREDENTIALS>"

api = genius.Genius(access_token=GENIUSCREDS,                   # API key provided by Genius
                    verbose=True,                               # turn off status messages
                    remove_section_headers=False,               # remove section headers(e.g. [Chorus]) from lyrics
                    skip_non_songs=False,                       # attempts to skip non-songs (e.g. track listings)
                    excluded_terms=["(Remix)", "(Live)"],       # exclude songs with these words in their title
                    timeout=25,                                 # time before quitting on response (seconds)
                    retries=5)                                  # number of retries in case of timeouts and errors

# %% [markdown]
# ## 2.2 Get the lyrics <a name="22-bullet"></a>

# %%
ARTIST_NAME = "Eminem"

# %% [markdown]
# ### a) including non-songs (skits, snippets, etc.)

# %%
api.skip_non_songs = False

artist_all = api.search_artist(ARTIST_NAME)
# Out:
# Searching for songs by Eminem...
#
# Song 1: "Rap God"
# Song 2: "Killshot"
# Song 3: "Godzilla"
# Song 4: "Lose Yourself"
# Song 5: "The Monster"
# Song 6: "Lucky You"
# Song 7: "The Ringer"
# Song 8: "River"
# Song 9: "Venom"
# Song 10: "Stan"
# Song 11: "Berzerk"
# Song 12: "Without Me"
# Song 13: "Not Alike"
# Song 14: "Fall"
# Song 15: "The Real Slim Shady"
# Song 16: "’Till I Collapse"
# Song 17: "Kamikaze"
# Song 18: "Walk on Water"
# Song 19: "Love the Way You Lie"
# Song 20: "Bad Guy"
# Song 21: "8 Mile: B-Rabbit vs Papa Doc"
# Song 22: "Mockingbird"
# Song 23: "Not Afraid"
# Song 24: "Headlights"
# Song 25: "No Love"
# Song 26: "Survival"
# Song 27: "Beautiful"
# Song 28: "Greatest"
# Song 29: "When I’m Gone"
# Song 30: "Cleanin’ Out My Closet"
# Song 31: "My Name Is"
# Song 32: "Love Game"
# Song 33: "Superman"
# Song 34: "The Way I Am"
# Song 35: "Legacy"
# Song 36: "Unaccommodating"
# Song 37: "Space Bound"
# Song 38: "Like Toy Soldiers"
# Song 39: "Guts Over Fear"
# Song 40: "Sing for the Moment"
# Song 41: "Gnat"
# Song 42: "Marshall Mathers"
# Song 43: "Stronger Than I Was"
# Song 44: "Believe"
# Song 45: "Kill You"
# Song 46: "Evil Twin"
# Song 47: "Detroit vs. Everybody"
# Song 48: "Untouchable"
# Song 49: "Darkness"
# Song 50: "Criminal"
# Song 51: "Kim"
# Song 52: "So Much Better"
# Song 53: "Beautiful Pain"
# Song 54: "I’m Back"
# Song 55: "You Gon’ Learn"
# Song 56: "Rhyme or Reason"
# Song 57: "Campaign Speech"
# Song 58: "Chloraseptic (Remix)"
# Song 59: "White America"
# Song 60: "Stepping Stone"
# Song 61: "Just Don’t Give a Fuck"
# Song 62: "Infinite"
# Song 63: "Kings Never Die"
# Song 64: "Asshole"
# Song 65: "Wicked Ways"
# Song 66: "Good Guy"
# Song 67: "So Far..."
# Song 68: "Shake That"
# Song 69: "Phenomenal"
# Song 70: "Normal"
# Song 71: "Role Model"
# Song 72: "Premonition (Intro)"
# Song 73: "Zeus"
# Song 74: "Guilty Conscience"
# Song 75: "Offended"
# Song 76: "Brainless"
# Song 77: "The Warning"
# Song 78: "FACK"
# Song 79: "25 to Life"
# Song 80: "Leaving Heaven"
# Song 81: "Those Kinda Nights"
# Song 82: "Hailie’s Song"
# Song 83: "Ass Like That"
# Song 84: "Bitch Please II"
# Song 85: "Marsh"
# Song 86: "Business"
# Song 87: "Just Lose It"
# Song 88: "Arose"
# Song 89: "I Will"
# Song 90: "Cold Wind Blows"
# Song 91: "Framed"
# Song 92: "8 Mile"
# Song 93: "Drug Ballad"
# Song 94: "Brain Damage"
# Song 95: "Chloraseptic"
# Song 96: "My Darling"
# Song 97: "Bad Husband"
# Song 98: "Going Through Changes"
# Song 99: "Cinderella Man"
# Song 100: "We Made You"
# Song 101: "Yah Yah"
# Song 102: "Still Shady"
# Song 103: "Rock Bottom"
# Song 104: "Castle"
# Song 105: "Soldier"
# Song 106: "Like Home"
# Song 107: "No Regrets"
# Song 108: "8 Mile: Lotto vs B-Rabbit"
# Song 109: "Who Knew"
# Song 110: "Nowhere Fast"
# Song 111: "8 Mile: Lyckety-Splyt vs B-Rabbit"
# Song 112: "Baby"
# Song 113: "Square Dance"
# Song 114: "Insane"
# Song 115: "Still Don’t Give a Fuck"
# Song 116: "My Dad’s Gone Crazy"
# Song 117: "Déjà Vu"
# Song 118: "3 a.m."
# Song 119: "Alfred’s Theme"
# Song 120: "Crack a Bottle"
# Song 121: "Lock It Up"
# Song 122: "Groundhog Day"
# Song 123: "Eminem Freestyles on Tim Westwood | 2009"
# Song 124: "Farewell"
# Song 125: "In Your Head"
# Song 126: "Remind Me"
# Song 127: "Rain Man"
# Song 128: "Stay Wide Awake"
# Song 129: "If I Had..."
# Song 130: "In Too Deep"
# Song 131: "Go to Sleep"
# Song 132: "Little Engine"
# Song 133: "Talkin’ 2 Myself"
# Song 134: "Remember Me?"
# Song 135: "Under the Influence"
# Song 136: "Tragic Endings"
# Song 137: "Won’t Back Down"
# Song 138: "Never Love Again"
# Song 139: "Stepdad"
# Song 140: "Heat"
# Song 141: "Almost Famous"
# Song 142: "Seduction"
# Song 143: "My Mom"
# Song 144: "Bagpipes from Baghdad"
# Song 145: "Nail in the Coffin"
# Song 146: "Doe Rae Me (Hailie’s Revenge)"
# Song 147: "Tone Deaf"
# Song 148: "Book of Rhymes"
# Song 149: "Yellow Brick Road"
# Song 150: "On Fire"
# Song 151: "When the Music Stops"
# Song 152: "Rabbit Run"
# Song 153: "Underground"
# Song 154: "Just the Two of Us"
# Song 155: "No Apologies"
# Song 156: "As the World Turns"
# Song 157: "You Don’t Know"
# Song 158: "Die Alone"
# Song 159: "Desperation"
# Song 160: "Need Me"
# Song 161: "W.T.P."
# Song 162: "Say Goodbye Hollywood"
# Song 163: "Difficult"
# Song 164: "So Bad"
# Song 165: "Em Calls Paul (Skit) [2018]"
# Song 166: "Same Song & Dance"
# Song 167: "Untitled"
# Song 168: "You’re Never Over"
# Song 169: "Amityville"
# Song 170: "I’m Shady"
# Song 171: "Parking Lot (Skit)"
# Song 172: "Mosh"
# Song 173: "The Kids"
# Song 174: "Bully"
# Song 175: "Fine Line"
# Song 176: "My Syllables"
# Song 177: "Drips"
# Song 178: "Don’t Front"
# Song 179: "Despicable"
# Song 180: "Medicine Ball"
# Song 181: "Discombobulated"
# Song 182: "Crazy in Love"
# Song 183: "Cum on Everybody"
# Song 184: "Spend Some Time"
# Song 185: "Hello"
# Song 186: "These Demons"
# Song 187: "Must Be the Ganja"
# Song 188: "Higher"
# Song 189: "Careful What You Wish For"
# Song 190: "Girls (Limp Bizkit Diss)"
# Song 191: "Say What You Say"
# Song 192: "Right for Me"
# Song 193: "Kick Off (Freestyle)"
# Song 194: "Love You More"
# Song 195: "Guns Blazing"
# Song 196: "Puke"
# Song 197: "Music Box"
# Song 198: "G.O.A.T."
# Song 199: "One Shot 2 Shot"
# Song 200: "Encore / Curtains Down"
# Song 201: "Evil Deeds"
# Song 202: "My Fault"
# Song 203: "Elevator"
# Song 204: "Eminem Freestyles on Tim Westwood | 2010"
# Song 205: "Big Weenie"
# Song 206: "Favorite Bitch"
# Song 207: "We As Americans"
# Song 208: "Killer"
# Song 209: "Ken Kaniff (Skit) [2000]"
# Song 210: "Foolish Pride"
# Song 211: "Revival (Interlude)"
# Song 212: "Quitter (Everlast Diss)"
# Song 213: "That’s All She Wrote (Solo Version)"
# Song 214: "Old Time’s Sake"
# Song 215: "Lose Yourself (Original Demo Version)"
# Song 216: "Buffalo Bill"
# Song 217: "Never Enough"
# Song 218: "Can I Bitch"
# Song 219: "The Sauce"
# Song 220: "313"
# Song 221: "8 Mile: The Lunch Truck Battle"
# Song 222: "’97 Bonnie & Clyde"
# Song 223: "My 1st Single"
# Song 224: "Low Down, Dirty"
# Song 225: "8 Mile: 313 Cypher (Chin Tiki Girls)"
# Song 226: "2.0 Boys"
# Song 227: "Get You Mad"
# Song 228: "She Loves Me"
# Song 229: "Session One"
# Song 230: "Alfred (Interlude)"
# Song 231: "Steve Berman (Skit) [2000]"
# Song 232: "It’s O.K."
# Song 233: "Nowhere Fast (Extended Version)"
# Song 234: "Drop the Bomb on ’Em"
# Song 235: "Taking My Ball"
# Song 236: "Murder, Murder"
# Song 237: "Hellbound"
# Song 238: "Open Mic"
# Song 239: "The Kiss (Skit)"
# Song 240: "Any Man (Fucking Crazy)"
# Song 241: "Ken Kaniff (Skit) [1999]"
# Song 242: "Demon Inside"
# Song 243: "Stimulate"
# Song 244: "Ridaz"
# Song 245: "Tonite"
# Song 246: "Remind Me (Intro)"
# Song 247: "Public Service Announcement 2000"
# Song 248: "Jimmy Crack Corn"
# Song 249: "Dr. West (Skit)"
# Song 250: "Listen To Your Heart"
# Song 251: "The Apple"
# Song 252: "Facebook Q&A"
# Song 253: "Cocaine"
# Song 254: "Stepdad (Intro)"
# Song 255: "Alfred (Outro)"
# Song 256: "I Remember (Dedication to Whitey Ford/Everlast Diss)"
# Song 257: "Bad Influence"
# Song 258: "Ricky Ticky Toc"
# Song 259: "No One’s Iller"
# Song 260: "Fly Away"
# Song 261: "1997 Rap Olympics"
# Song 262: "Backstabber"
# Song 263: "Hell Breaks Loose"
# Song 264: "Public Service Announcement"
# Song 265: "The Interview (Freestyle)"
# Song 266: "Microphone Freestyle"
# Song 267: "Monkey See, Monkey Do"
# Song 268: "3 Verses"
# Song 269: "Ballin’ Uncontrollably"
# Song 270: "Bitch (Skit)"
# Song 271: "Steve Berman (Skit) [2009]"
# Song 272: "Em Calls Paul (Skit) [2004]"
# Song 273: "Key (Skit)"
# Song 274: "Paul (Skit) [2009]"
# Song 275: "8 Mile: Sweet Home Alabama Freestyle"
# Song 276: "Till Hell Freezes Over"
# Song 277: "4 Verses"
# Song 278: "The Re-Up"
# Song 279: "Oh No"
# Song 280: "I’m Having a Relapse"
# Song 281: "Public Enemy #1"
# Song 282: "Bump Heads (Ja Rule Diss)"
# Song 283: "Armaggedon (The Invasion Part 3)"
# Song 284: "Paul (Skit) [1999]"
# Song 285: "Searchin’"
# Song 286: "Rhyme Time With Eminem"
# Song 287: "Wee Wee"
# Song 288: "Never 2 Far"
# Song 289: "Paul Rosenberg (Skit) [2002]"
# Song 290: "Slim Shady (Intro)"
# Song 291: "Weed Lacer"
# Song 292: "My Name Is (Original)"
# Song 293: "Em360 Rapcity Backroom Freestyle"
# Song 294: "The Equalizer : Soundtrack"
# Song 295: "Jealousy Woes II"
# Song 296: "8 Mile: Marv Won vs B-Rabbit"
# Song 297: "It’s Been Real"
# Song 298: "Maxine"
# Song 299: "Greg"
# Song 300: "8 Mile Background Music"
# Song 301: "Tonya (Skit)"
# Song 302: "Kurt Loder Car Freestyle"
# Song 303: "Steve Berman (Skit) [2002]"
# Song 304: "2012 Something From Nothing: Art of Rap Freestyle"
# Song 305: "My Name Is (Original Version)"
# Song 306: "Our House"
# Song 307: "Rap City Freestyle"
# Song 308: "Intro (Curtain Call)"
# Song 309: "We’re Back"
# Song 310: "The Conspiracy Freestyle"
# Song 311: "Alfred (Intro)"
# Song 312: "Soap (Skit)"
# Song 313: "Emulate"
# Song 314: "Curtains Close (Skit)"
# Song 315: "I Get Money (Remix)"
# Song 316: "Devil’s Night Intro"
# Song 317: "50 Ways"
# Song 318: "Rap City"
# Song 319: "W.E.G.O. (Interlude)"
# Song 320: "It’s Only Fair to Warn [Freestyle]"
# Song 321: "Lounge (Skit)"
# Song 322: "Letter to Tupac’s Mother"
# Song 323: "The Real Slim Shady (Clean)"
# Song 324: "Freak"
# Song 325: "Mr. Mathers (Skit)"
# Song 326: "Invasion (The Realest)"
# Song 327: "So Many Styles"
# Song 328: "Thus Far (Interlude)"
# Song 329: "8 Mile: D’Phuzion vs B-Rabbit"
# Song 330: "Just Rhymin’ with Proof"
# Song 331: "8 Mile: Lily’s Lullaby"
# Song 332: "Everything"
# Song 333: "Fuck You"
# Song 334: "Paul (Skit) [2004]"
# Song 335: "Rap City Freestyle (Keeping It Raw)"
# Song 336: "Things Get Worse (Lost Version)"
# Song 337: "1-833-2GET-REV (REVIVAL Voicemail)"
# Song 338: "Curtains Up (Skit) [2004]"
# Song 339: "Nut Up"
# Song 340: "Curtains Up (Skit) [2002]"
# Song 341: "Hazardous Youth"
# Song 342: "Wanksta (Eminem’s Version)"
# Song 343: "God Is Cleaning Out My Closet"
# Song 344: "Give Me the Ball"
# Song 345: "Anger Management"
# Song 346: "Off The Dome Freestyle"
# Song 347: "Kill My Pain (Mixup)"
# Song 348: "Freestyle (Gone Crazy)"
# Song 349: "My Drug Addiction"
# Song 350: "The People’s Champ (Intro)"
# Song 351: "First Word Freestyle"
# Song 352: "Eminem’s Tattoos"
# Song 353: "1998 Wake Up Show Freestyle"
# Song 354: "Stan (Live from the 43rd Annual Grammy Awards)"
# Song 355: "Fubba U Cubba Cubba"
# Song 356: "8 Mile: Cheddar Bob Freestyle"
# Song 357: "XL Show Freestyle"
# Song 358: "Whether or Not"
# Song 359: "My Salsa"
# Song 360: "Zane Lowe BBC Radio Interview Part 1"
# Song 361: "Shade 45 Freestyle"
# Song 362: "ESPN Halftime Booth Interview"
# Song 363: "Pooh Butt Day"
# Song 364: "8 Mile: B-Rabbit vs Supa Emcee"
# Song 365: "Freestyle (The Watcher)"
# Song 366: "Tim Westwood Freestyle"
# Song 367: "8 Mile: Maurice Grant vs B-Rabbit"
# Song 368: "Final Thought (Skit)"
# Song 369: "Baruch College Session"
# Song 370: "Infinite (F.B.T. Remix)"
# Song 371: "Zucker im Kaffee (Sugar in the coffee)"
# Song 372: "Freestyle (Light Speed)"
# Song 373: "Shady Narcotics"
# Song 374: "Tylenol Island"
# Song 375: "My Name Is (Radio Edit)"
# Song 376: "Syllables (Remix)"
# Song 377: "Relapse [Booklet]"
# Song 378: "12 Days of Diss-Mas"
# Song 379: "Everybody’s Looking at Me"
# Song 380: "Steve Berman (Skit) [2001]"
# Song 381: "2004 Tim Westwood Freestyle"
# Song 382: "Crackers And Cheese"
# Song 383: "Three Headed Monster*"
# Song 384: "Recovery [Booklet]"
# Song 385: "Encore [Booklet]"
# Song 386: "Take The World With Me"
# Song 387: "Nowhere Fast (iHeartRadio Music Awards 2018)"
# Song 388: "Richard (Solo Version)"
# Song 389: "The Monster Explained"
# Song 390: "1999"
# Song 391: "My Fault (Pizza Mix)"
# Song 392: "Eminem Freestyle On The Farmclub"
# Song 393: "Step Right Up"
# Song 394: "1997 Freestyle Live at Wetlands, NYC"
# Song 395: "The Way I Am (Danny Lohner Remix)"
# Song 396: "Marshall Mathers (Snippet)"
# Song 397: "Mommy (Skit)"
# Song 398: "Rap City Freestyle (I’m a Big Deal)"
# Song 399: "Power 92.3 Freestyle"
# Song 400: "Crack a Bottle (Original Demo)"
# Song 401: "W.T.P. (Remix)"
# Song 402: "1996 Underground Freestyle"
# Song 403: "Bad Meets Evil (Original)"
# Song 404: "My Conscience"
# Song 405: "Superman (Cry Me A River Remix)"
# Song 406: "Public Service Announcement (2006)"
# Song 407: "Walk On Water/Stan/Love The Way You Lie (SNL Medley)"
# Song 408: "Rap Battle (1994)"
# Song 409: "Public Service Announcement (SSLP)"
# Song 410: "’97 Blazer"
# Song 411: "Letter To Detroit"
# Song 412: "Hip Hop"
# Song 413: "Phone Tap (Freestyle)"
# Song 414: "Fuck That Shit (Rapture)"
# Song 415: "Eminem Freestyle (Hollywood Homicide)"
# Song 416: "Role Model (Demo)"
# Song 417: "Killer (Original)"
# Song 418: "Radio Freestyle 1"
# Song 419: "Ghost Stories"
# Song 420: "Pick It Up"
# Song 421: "Brenda (Skit) (1998)"
# Song 422: "Lose Yourself (Drum & Bass Remix)"
# Song 423: "Food Stamp (Phone Tap Freestyle)"
# Song 424: "Cut Back"
# Song 425: "Just Don’t Give a #?@! (Radio Edit)"
# Song 426: "Zane Lowe BBC Radio Interview Part 2"
# Song 427: "Murder Murder (Next Friday)"
# Song 428: "Guilty Conscience (Radio Extra Clean W/New Hook)"
# Song 429: "Cleanin’ Out My Closet (Drum & Bass Remix)"
# Song 430: "Serious"
# Song 431: "Stuff To Never Rhyme (The Don’ts)"
# Song 432: "Cock Massage (Skit)"
# Song 433: "Beautiful (Radio Edit)"
# Song 434: "Unreleased Songs [Discography List]"
# Song 435: "MC Hammer vs. Vanilla Ice"
# Song 436: "I Kissed a Boy"
# Song 437: "Berzerk Explained"
# Song 438: "Brain Damage (Snippet)"
# Song 439: "Infinite [Credits]"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Eminem-lose-yourself-instrumental-lyrics
# Song 440: "Lose Yourself (Instrumental)"
# Song 441: "Radio Freestyle 2"
# Song 442: "Criminal (Snippet)"
# Song 443: "What Colour Is Soul"
# Song 444: "Hate Me Now Freestyle"
# Song 445: "Don’t Chew With Your Mouth Full"
# Song 446: "Role Model (Clean Version)"
# Song 447: "Ariel (Skit)"
# Song 448: "Eminem, Paul Rosenberg Intro"
# Song 449: "C’mon Everybody"
# Song 450: "Guilty Conscience (Radio Version)"
# Song 451: "Radio Freestyle 3"
# Song 452: "Stolen Power"
# Song 453: "Mic Check One Two"
# Song 454: "If I Had (Radio Edit)"
# Song 455: "Open Mic Feb. 17, 1996"
# Song 456: "Verse 1"
# Song 457: "Dirty Steve (Skit)"
# Song 458: "Cancerous (Freestyle)"
# Song 459: "Starting To Look Like An M&M!"
# Song 460: "What Time You Sucking It*"
# Song 461: "Broke Day (Snippet of ”It’s Okay”)"
# Song 462: "Verse 3"
# Song 463: "Without Me (A Cappella)"
# Song 464: "DJ Fashion Freestyle"
# Song 465: "Eminem Music Videos"
# Song 466: "Just Don’t Give a Fuck (A Cappella)"
# Song 467: "Benzino II (Skit)"
# Song 468: "The Slim Shady Show Freestyle"
# Song 469: "Guilty Conscience (A Cappella)"
# Song 470: "Ode To Detroit"
# Song 471: "Don’t Call Me Marshall (Intro)"
# Song 472: "Breaking News (Intro)"
# Song 473: "I Get Money"
# Song 474: "Freestyle (Attitude)"
# Song 475: "Second Chance"
# Song 476: "Taj Mahal (Skit)"
# Song 477: "Rap Game (Solo Mix)"
# Song 478: "Wicked Shit Freestyle"
# Song 479: "Male Prostitute"
# Song 480: "The Kids (Unreleased Demo)"
# Song 481: "My Name Is (Snippet)"
# Song 482: "Passin’ out concussions"
# Song 483: "Drop It Like It’s Hot Freestyle"
# Song 484: "Verse 2"
# Song 485: "Man With Van (Skit)"
# Song 486: "Nicole (Skit)"
# Song 487: "The Half-Time Show Freestyle"
# Song 488: "Fat Beats (Skit)"
# Song 489: "Keys To The City"
# Song 490: "Canibus Impression Freestyle"
# Song 491: "Record Store 1 (Skit)"
# Song 492: "Insult to Injury"
# Song 493: "Fuck You (Lab Rat Remix)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Eminem-my-name-is-instrumental-lyrics
# Song 494: "My Name Is (Instrumental)"
# Song 495: "Business (A Cappella)"
# Song 496: "I’m Shady (Snippet)"
# Song 497: "Victory (Remix)"
# Song 498: "Bump Heads - DJ Green Lantern Version"
# Song 499: "Guilty Conscience (Snippet)"
# Song 500: "Junko (Skit)"
# Song 501: "Crack A Bottle (Shady Remix)"
# Song 502: "Any Word Freestyle"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Eminem-without-me-instrumental-lyrics
# Song 503: "Without Me (Instrumental)"
# Song 504: "What’s Your Intent?"
# Song 505: "Mystical Diss"
# Song 506: "Slut Phone Call (Skit)"
# Song 507: "Curtis (Skit)"
# Song 508: "Jesse (Skit)"
# Song 509: "Cut Back (Leak)"
# Song 510: "Jimmy Crack Corn (Cashis Vocal Mix (EX))"
# Song 511: "PhatBeats Prank Call"
# Song 512: "Rex (Skit)"
# Song 513: "Mariah Carey Voicemail (Anger Management Tour 2005)"
# Song 514: "Record Store 2 (Skit)"
# Song 515: "Slim Shady"
# Song 516: "Run Your Jewels (Snippet)"
# Song 517: "Medicine Man (Only Eminem)"
# Song 518: "Hot 100 Chart History"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Eminem-just-dont-give-a-fuck-instrumental-lyrics
# Song 519: "Just Don’t Give a Fuck (Instrumental)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Eminem-sing-for-the-moment-instrumental-lyrics
# Song 520: "Sing for the Moment (Instrumental)"
# Song 521: "Mancow (Freestyle)"
# Song 522: "Lose Yourself (Live at the 92nd Academy Awards)"
# Song 523: "Superman (Clean Radio Edit)"
# Song 524: "The Real Slim Shady (Murda Mixtape Version)"
# Song 525: "Eminem Full Discography"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Eminem-guilty-conscience-instrumental-lyrics
# Song 526: "Guilty Conscience (Instrumental)"
# Song 527: "The Kids (Demo)"
# Song 528: "Eminem - Get You Mad (Türkçe Çeviri)"
# Song 529: "Real Slim Shady (EDIT)"
# Song 530: "WJLB 1998 Promo"
# Song 531: "Interview With Hot 97 (Disses Benzino)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Eminem-cleanin-out-my-closet-instrumental-lyrics
# Song 532: "Cleanin’ Out My Closet (Instrumental)"
# Song 533: "Everything I Do"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Eminem-the-real-slim-shady-instrumental-lyrics
# Song 534: "The Real Slim Shady (Instrumental)"
# Song 535: "Cannon for nick"
# Song 536: "Rap Game (Bump Heads)"
# Song 537: "Low, Down, Dirty (Unmastered Sequence version)"
# Song 538: "Revival [Credits]"
# Song 539: "The ‘N’ Bomb"
# Song 540: "Whoo Kid Freestyle"
# Song 541: "Rolling Stone Q/A Exclusive 2013"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Eminem-the-way-i-am-instrumental-lyrics
# Song 542: "The Way I Am (Instrumental)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Eminem-stan-instrumental-lyrics
# Song 543: "Stan (Instrumental)"
# Song 544: "Rap God (Lyrics on Genius)"
# Song 545: "Anger Management (Turkish Translation)"
# Song 546: "I’m Back/Kill You/Under the Influence (Live in California)"
# Song 547: "Hit ’Em Up"
# Song 548: "Microphone (Studio Edit)"
# Song 549: "#hot16challenge2"
# Song 550: "Business - Live At The Palace of Auburn Hills, Detroit / 2002"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Eminem-mockingbird-instrumental-lyrics
# Song 551: "Mockingbird (Instrumental)"
# Song 552: "Eminem - Zeus (ترجمه فارسی)"
# Song 553: "8 Mile (Live in Dublin)"
# Song 554: "Basket Case Freestyle"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Eminem-when-im-gone-instrumental-lyrics
# Song 555: "When I’m Gone (Instrumental)"
# Song 556: "Premonition (PL)"
# Song 557: "No Love (Remix)"
# Song 558: "We Made You (Digital Single Version)"
# Song 559: "Still Number One"
# Song 560: "NOT KEYS TO THE CITY"
# Song 561: "The Storm (2017 BET Cypher Český překlad)"
# Song 562: "I Like A Girl Freestyle"
# Song 563: "The Murderous Shady"
# Song 564: "Ghost"
# Song 565: "Canopy Freestyle"
# Song 566: "Eminem - Difficult (MAGYAR FORDÍTÁS)"
# Song 567: "My Πame is"
# Song 568: "So Bad (Remix)"
# Song 569: "Bangkok Playmates"
# Song 570: "One Chance"
# Song 571: "Eminem - Lose yourself (Translation in Arabic)"
# Song 572: "I’m A Ghost"
# Song 573: "Brenda (Skit)"
# Song 574: "Eminem - Hello (Türkçe Çeviri)"
# Song 575: "Fuck Obie (Skit)"
# Song 576: "The Wake Up Show Freestyle"
# Song 577: "Holy fucking shit..... *Punches drywall*"
# Song 578: "Controvery (Skit)"
# Song 579: "Public Service Announcement 2013"
# Song 580: "Kill Em’ All"
# Song 581: "It’s the real slim shady"
# Song 582: "Premonition (Intro) (Kurdish Subtitle)"
# Song 583: "Elen diss track"
# Song 584: "The Kiss (Skit) German translation"
# Song 585: "Shinin (Unreleased)"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Shabaam-sahdeeq-5-star-generals-instrumental-lyrics
# Song 586: "Ass Like That [slowed] remix"
# Done. Found 586 songs.

# %% [markdown]
# ### b) only songs

# %%
api.skip_non_songs = True

artist_songs = api.search_artist(ARTIST_NAME)
# Out:
# Searching for songs by Eminem...
#
# Song 1: "Rap God"
# Song 2: "Killshot"
# Song 3: "Godzilla"
# Song 4: "Lose Yourself"
# Song 5: "The Monster"
# Song 6: "Lucky You"
# Song 7: "The Ringer"
# Song 8: "River"
# Song 9: "Venom"
# Song 10: "Stan"
# Song 11: "Berzerk"
# Song 12: "Without Me"
# Song 13: "Not Alike"
# Song 14: "Fall"
# Song 15: "The Real Slim Shady"
# Song 16: "’Till I Collapse"
# Song 17: "Kamikaze"
# Song 18: "Walk on Water"
# Song 19: "Love the Way You Lie"
# Song 20: "Bad Guy"
# Song 21: "8 Mile: B-Rabbit vs Papa Doc"
# Song 22: "Mockingbird"
# Song 23: "Not Afraid"
# Song 24: "Headlights"
# Song 25: "No Love"
# Song 26: "Survival"
# Song 27: "Beautiful"
# Song 28: "Greatest"
# Song 29: "When I’m Gone"
# Song 30: "Cleanin’ Out My Closet"
# Song 31: "My Name Is"
# Song 32: "Love Game"
# Song 33: "Superman"
# Song 34: "The Way I Am"
# Song 35: "Legacy"
# Song 36: "Unaccommodating"
# Song 37: "Space Bound"
# Song 38: "Like Toy Soldiers"
# Song 39: "Guts Over Fear"
# Song 40: "Sing for the Moment"
# Song 41: "Gnat"
# Song 42: "Marshall Mathers"
# Song 43: "Stronger Than I Was"
# Song 44: "Believe"
# Song 45: "Kill You"
# Song 46: "Evil Twin"
# Song 47: "Detroit vs. Everybody"
# Song 48: "Untouchable"
# Song 49: "Darkness"
# Song 50: "Criminal"
# Song 51: "Kim"
# Song 52: "So Much Better"
# Song 53: "Beautiful Pain"
# Song 54: "I’m Back"
# Song 55: "You Gon’ Learn"
# Song 56: "Rhyme or Reason"
# Song 57: "Campaign Speech"
# "Chloraseptic (Remix)" is not valid. Skipping.
# Song 58: "White America"
# Song 59: "Stepping Stone"
# "The Hills (Eminem Remix)" is not valid. Skipping.
# Song 60: "Just Don’t Give a Fuck"
# Song 61: "Infinite"
# Song 62: "Kings Never Die"
# Song 63: "Asshole"
# Song 64: "Wicked Ways"
# Song 65: "Good Guy"
# Song 66: "So Far..."
# Song 67: "Shake That"
# Song 68: "Phenomenal"
# Song 69: "Normal"
# Song 70: "Role Model"
# Song 71: "Premonition (Intro)"
# Song 72: "Zeus"
# Song 73: "Guilty Conscience"
# Song 74: "Offended"
# Song 75: "Brainless"
# Song 76: "The Warning"
# Song 77: "FACK"
# Song 78: "25 to Life"
# Song 79: "Leaving Heaven"
# Song 80: "Those Kinda Nights"
# Song 81: "Hailie’s Song"
# Song 82: "Ass Like That"
# "Runnin’ (Dying to Live)" is not valid. Skipping.
# Song 83: "Bitch Please II"
# Song 84: "Marsh"
# Song 85: "Business"
# Song 86: "Just Lose It"
# Song 87: "Arose"
# Song 88: "I Will"
# Song 89: "Cold Wind Blows"
# Song 90: "Framed"
# Song 91: "8 Mile"
# Song 92: "Drug Ballad"
# Song 93: "Brain Damage"
# Song 94: "Chloraseptic"
# Song 95: "My Darling"
# Song 96: "Bad Husband"
# Song 97: "Going Through Changes"
# Song 98: "Cinderella Man"
# Song 99: "We Made You"
# Song 100: "Yah Yah"
# Song 101: "Still Shady"
# Song 102: "Rock Bottom"
# Song 103: "Castle"
# Song 104: "Soldier"
# Song 105: "Like Home"
# Song 106: "No Regrets"
# Song 107: "8 Mile: Lotto vs B-Rabbit"
# Song 108: "Who Knew"
# Song 109: "Nowhere Fast"
# Song 110: "8 Mile: Lyckety-Splyt vs B-Rabbit"
# Song 111: "Baby"
# Song 112: "Square Dance"
# Song 113: "Insane"
# Song 114: "Still Don’t Give a Fuck"
# Song 115: "My Dad’s Gone Crazy"
# Song 116: "Déjà Vu"
# Song 117: "3 a.m."
# Song 118: "Alfred’s Theme"
# Song 119: "Crack a Bottle"
# Song 120: "Lock It Up"
# Song 121: "Groundhog Day"
# Song 122: "Eminem Freestyles on Tim Westwood | 2009"
# Song 123: "Farewell"
# Song 124: "In Your Head"
# Song 125: "Remind Me"
# Song 126: "Rain Man"
# Song 127: "Stay Wide Awake"
# Song 128: "If I Had..."
# Song 129: "In Too Deep"
# Song 130: "Go to Sleep"
# Song 131: "Little Engine"
# Song 132: "Talkin’ 2 Myself"
# Song 133: "Remember Me?"
# Song 134: "Under the Influence"
# Song 135: "Tragic Endings"
# Song 136: "Won’t Back Down"
# Song 137: "Never Love Again"
# Song 138: "Stepdad"
# Song 139: "Heat"
# Song 140: "Almost Famous"
# Song 141: "Seduction"
# Song 142: "My Mom"
# Song 143: "Bagpipes from Baghdad"
# Song 144: "Nail in the Coffin"
# Song 145: "Doe Rae Me (Hailie’s Revenge)"
# Song 146: "Tone Deaf"
# Song 147: "Book of Rhymes"
# Song 148: "Yellow Brick Road"
# Song 149: "On Fire"
# Song 150: "When the Music Stops"
# Song 151: "Rabbit Run"
# Song 152: "Underground"
# Song 153: "Just the Two of Us"
# Song 154: "No Apologies"
# Song 155: "As the World Turns"
# Song 156: "You Don’t Know"
# Song 157: "Die Alone"
# Song 158: "Desperation"
# Song 159: "Need Me"
# Song 160: "W.T.P."
# Song 161: "Say Goodbye Hollywood"
# Song 162: "Difficult"
# Song 163: "So Bad"
# "Em Calls Paul (Skit) [2018]" is not valid. Skipping.
# Song 164: "Same Song & Dance"
# Song 165: "Untitled"
# Song 166: "You’re Never Over"
# Song 167: "Amityville"
# Song 168: "I’m Shady"
# "Parking Lot (Skit)" is not valid. Skipping.
# Song 169: "Mosh"
# Song 170: "The Kids"
# Song 171: "Bully"
# Song 172: "Fine Line"
# Song 173: "My Syllables"
# Song 174: "Drips"
# Song 175: "Don’t Front"
# Song 176: "Despicable"
# Song 177: "Medicine Ball"
# Song 178: "Discombobulated"
# Song 179: "Crazy in Love"
# Song 180: "Cum on Everybody"
# Song 181: "Spend Some Time"
# Song 182: "Hello"
# Song 183: "These Demons"
# Song 184: "Must Be the Ganja"
# Song 185: "Higher"
# Song 186: "Careful What You Wish For"
# Song 187: "Girls (Limp Bizkit Diss)"
# Song 188: "Say What You Say"
# Song 189: "Right for Me"
# Song 190: "Kick Off (Freestyle)"
# Song 191: "Love You More"
# Song 192: "Guns Blazing"
# Song 193: "Puke"
# Song 194: "Music Box"
# Song 195: "G.O.A.T."
# Song 196: "One Shot 2 Shot"
# Song 197: "Encore / Curtains Down"
# Song 198: "Evil Deeds"
# Song 199: "My Fault"
# Song 200: "Elevator"
# Song 201: "Eminem Freestyles on Tim Westwood | 2010"
# "Paul (Skit)" is not valid. Skipping.
# Song 202: "Big Weenie"
# Song 203: "Favorite Bitch"
# Song 204: "We As Americans"
# Song 205: "Killer"
# "Ken Kaniff (Skit) [2000]" is not valid. Skipping.
# Song 206: "Foolish Pride"
# Song 207: "Revival (Interlude)"
# Song 208: "Quitter (Everlast Diss)"
# Song 209: "That’s All She Wrote (Solo Version)"
# Song 210: "Old Time’s Sake"
# Song 211: "Lose Yourself (Original Demo Version)"
# Song 212: "Buffalo Bill"
# Song 213: "Never Enough"
# Song 214: "Can I Bitch"
# Song 215: "The Sauce"
# Song 216: "313"
# Song 217: "8 Mile: The Lunch Truck Battle"
# Song 218: "’97 Bonnie & Clyde"
# Song 219: "My 1st Single"
# Song 220: "Low Down, Dirty"
# Song 221: "8 Mile: 313 Cypher (Chin Tiki Girls)"
# Song 222: "2.0 Boys"
# Song 223: "Get You Mad"
# Song 224: "She Loves Me"
# Song 225: "Session One"
# Song 226: "Alfred (Interlude)"
# "Steve Berman (Skit) [2000]" is not valid. Skipping.
# Song 227: "It’s O.K."
# Song 228: "Nowhere Fast (Extended Version)"
# Song 229: "Drop the Bomb on ’Em"
# Song 230: "Taking My Ball"
# Song 231: "Murder, Murder"
# Song 232: "Hellbound"
# Song 233: "Open Mic"
# "The Kiss (Skit)" is not valid. Skipping.
# Song 234: "Any Man (Fucking Crazy)"
# "Ken Kaniff (Skit) [1999]" is not valid. Skipping.
# Song 235: "Demon Inside"
# "Lean Back (Remix)" is not valid. Skipping.
# Song 236: "Stimulate"
# Song 237: "Ridaz"
# Song 238: "Tonite"
# Song 239: "Remind Me (Intro)"
# Song 240: "Public Service Announcement 2000"
# Song 241: "Jimmy Crack Corn"
# "Dr. West (Skit)" is not valid. Skipping.
# Song 242: "Listen To Your Heart"
# Song 243: "The Apple"
# Song 244: "Facebook Q&A"
# Song 245: "Cocaine"
# Song 246: "Stepdad (Intro)"
# Song 247: "Alfred (Outro)"
# Song 248: "I Remember (Dedication to Whitey Ford/Everlast Diss)"
# Song 249: "Bad Influence"
# Song 250: "Ricky Ticky Toc"
# "Shake That (Remix)" is not valid. Skipping.
# Song 251: "No One’s Iller"
# Song 252: "Fly Away"
# Song 253: "1997 Rap Olympics"
# Song 254: "Backstabber"
# Song 255: "Hell Breaks Loose"
# Song 256: "Public Service Announcement"
# "The Interview (Freestyle)" is not valid. Skipping.
# Song 257: "Microphone Freestyle"
# Song 258: "Monkey See, Monkey Do"
# Song 259: "3 Verses"
# Song 260: "Ballin’ Uncontrollably"
# "Bitch (Skit)" is not valid. Skipping.
# "Steve Berman (Skit) [2009]" is not valid. Skipping.
# "Em Calls Paul (Skit) [2004]" is not valid. Skipping.
# "Key (Skit)" is not valid. Skipping.
# "Paul (Skit) [2009]" is not valid. Skipping.
# Song 261: "8 Mile: Sweet Home Alabama Freestyle"
# Song 262: "Till Hell Freezes Over"
# Song 263: "4 Verses"
# Song 264: "The Re-Up"
# Song 265: "Oh No"
# Song 266: "I’m Having a Relapse"
# Song 267: "Public Enemy #1"
# Song 268: "Bump Heads (Ja Rule Diss)"
# Song 269: "Armaggedon (The Invasion Part 3)"
# "Detroit Vs Everybody (Remix)" is not valid. Skipping.
# "Paul (Skit) [1999]" is not valid. Skipping.
# "Loyal to the Game (G-Unit Remix)" is not valid. Skipping.
# Song 270: "Searchin’"
# Song 271: "Rhyme Time With Eminem"
# Song 272: "Wee Wee"
# Song 273: "Never 2 Far"
# "Paul Rosenberg (Skit) [2002]" is not valid. Skipping.
# Song 274: "Slim Shady (Intro)"
# Song 275: "Weed Lacer"
# Song 276: "My Name Is (Original)"
# Song 277: "Em360 Rapcity Backroom Freestyle"
# Song 278: "The Equalizer : Soundtrack"
# Song 279: "Jealousy Woes II"
# Song 280: "8 Mile: Marv Won vs B-Rabbit"
# Song 281: "It’s Been Real"
# Song 282: "Maxine"
# Song 283: "Greg"
# Song 284: "8 Mile Background Music"
# "Tonya (Skit)" is not valid. Skipping.
# Song 285: "Kurt Loder Car Freestyle"
# "Steve Berman (Skit) [2002]" is not valid. Skipping.
# "Bang (Remix)" is not valid. Skipping.
# Song 286: "2012 Something From Nothing: Art of Rap Freestyle"
# Song 287: "My Name Is (Original Version)"
# Song 288: "Our House"
# Song 289: "Rap City Freestyle"
# Song 290: "Intro (Curtain Call)"
# Song 291: "We’re Back"
# Song 292: "The Conspiracy Freestyle"
# Song 293: "Alfred (Intro)"
# "Soap (Skit)" is not valid. Skipping.
# Song 294: "Emulate"
# "Curtains Close (Skit)" is not valid. Skipping.
# "I Get Money (Remix)" is not valid. Skipping.
# Song 295: "Devil’s Night Intro"
# Song 296: "50 Ways"
# "Unstoppable (Miqu remix)" is not valid. Skipping.
# Song 297: "Rap City"
# Song 298: "W.E.G.O. (Interlude)"
# Song 299: "It’s Only Fair to Warn [Freestyle]"
# "Lounge (Skit)" is not valid. Skipping.
# Song 300: "Letter to Tupac’s Mother"
# Song 301: "The Real Slim Shady (Clean)"
# Song 302: "Freak"
# "Mr. Mathers (Skit)" is not valid. Skipping.
# Song 303: "Invasion (The Realest)"
# Song 304: "So Many Styles"
# "Final Day (Tupac Thug Theory Remix)" is not valid. Skipping.
# Song 305: "Thus Far (Interlude)"
# Song 306: "8 Mile: D’Phuzion vs B-Rabbit"
# Song 307: "Just Rhymin’ with Proof"
# "Touch It (Remix 2.0)" is not valid. Skipping.
# Song 308: "8 Mile: Lily’s Lullaby"
# Song 309: "Everything"
# Song 310: "Fuck You"
# "Paul (Skit) [2004]" is not valid. Skipping.
# "Pistol Pistol (Remix)" is not valid. Skipping.
# "Celebrity (Remix)" is not valid. Skipping.
# Song 311: "Rap City Freestyle (Keeping It Raw)"
# "Hello Good Morning (Eminem Remix)" is not valid. Skipping.
# Song 312: "Things Get Worse (Lost Version)"
# Song 313: "1-833-2GET-REV (REVIVAL Voicemail)"
# "Curtains Up (Skit) [2004]" is not valid. Skipping.
# Song 314: "Nut Up"
# "Curtains Up (Skit) [2002]" is not valid. Skipping.
# "Don’t Go To Sleep [IMAKEKHAOS Remix]" is not valid. Skipping.
# Song 315: "Hazardous Youth"
# Song 316: "Wanksta (Eminem’s Version)"
# "Smack That (Remix)" is not valid. Skipping.
# Song 317: "God Is Cleaning Out My Closet"
# Song 318: "Give Me the Ball"
# "Bullet To The Brain (Remix)" is not valid. Skipping.
# Song 319: "Anger Management"
# Song 320: "Off The Dome Freestyle"
# Song 321: "Kill My Pain (Mixup)"
# "Perspective (Skit)" is not valid. Skipping.
# Song 322: "Freestyle (Gone Crazy)"
# Song 323: "My Drug Addiction"
# Song 324: "The People’s Champ (Intro)"
# Song 325: "First Word Freestyle"
# Song 326: "Eminem’s Tattoos"
# "8 Mile Road (G-Unit Remix)" is not valid. Skipping.
# Song 327: "1998 Wake Up Show Freestyle"
# "Stan (Live from the 43rd Annual Grammy Awards)" is not valid. Skipping.
# Song 328: "Fubba U Cubba Cubba"
# Song 329: "8 Mile: Cheddar Bob Freestyle"
# Song 330: "XL Show Freestyle"
# Song 331: "Whether or Not"
# Song 332: "My Salsa"
# "Zane Lowe BBC Radio Interview Part 1" is not valid. Skipping.
# Song 333: "Shade 45 Freestyle"
# "ESPN Halftime Booth Interview" is not valid. Skipping.
# Song 334: "Pooh Butt Day"
# Song 335: "8 Mile: B-Rabbit vs Supa Emcee"
# Song 336: "Freestyle (The Watcher)"
# Song 337: "Tim Westwood Freestyle"
# Song 338: "8 Mile: Maurice Grant vs B-Rabbit"
# "Final Thought (Skit)" is not valid. Skipping.
# Song 339: "Baruch College Session"
# "Infinite (F.B.T. Remix)" is not valid. Skipping.
# Song 340: "Zucker im Kaffee (Sugar in the coffee)"
# "Love The Way You Lie (Remix)" is not valid. Skipping.
# Song 341: "Freestyle (Light Speed)"
# Song 342: "Shady Narcotics"
# Song 343: "Tylenol Island"
# Song 344: "My Name Is (Radio Edit)"
# "Syllables (Remix)" is not valid. Skipping.
# "Relapse [Booklet]" is not valid. Skipping.
# Song 345: "12 Days of Diss-Mas"
# Song 346: "Everybody’s Looking at Me"
# "Steve Berman (Skit) [2001]" is not valid. Skipping.
# Song 347: "2004 Tim Westwood Freestyle"
# Song 348: "Crackers And Cheese"
# "Three Headed Monster*" is not valid. Skipping.
# "Recovery [Booklet]" is not valid. Skipping.
# "Topless (Remix)" is not valid. Skipping.
# "Encore [Booklet]" is not valid. Skipping.
# Song 349: "Take The World With Me"
# "Forever (Travis Barker Remix)" is not valid. Skipping.
# Song 350: "Nowhere Fast (iHeartRadio Music Awards 2018)"
# Song 351: "Richard (Solo Version)"
# Song 352: "The Monster Explained"
# Song 353: "1999"
# Song 354: "My Fault (Pizza Mix)"
# "Fattest Skinny Kid Alive" is not valid. Skipping.
# Song 355: "Eminem Freestyle On The Farmclub"
# Song 356: "Step Right Up"
# "1997 Freestyle Live at Wetlands, NYC" is not valid. Skipping.
# "The Way I Am (Danny Lohner Remix)" is not valid. Skipping.
# Song 357: "Marshall Mathers (Snippet)"
# "Mommy (Skit)" is not valid. Skipping.
# Song 358: "Rap City Freestyle (I’m a Big Deal)"
# "Ski Mask Way (Eminem Remix)" is not valid. Skipping.
# Song 359: "Power 92.3 Freestyle"
# Song 360: "Crack a Bottle (Original Demo)"
# "Bizarre (Skit) [2004]" is not valid. Skipping.
# "W.T.P. (Remix)" is not valid. Skipping.
# Song 361: "1996 Underground Freestyle"
# Song 362: "Bad Meets Evil (Original)"
# Song 363: "My Conscience"
# "Superman (Cry Me A River Remix)" is not valid. Skipping.
# Song 364: "Public Service Announcement (2006)"
# Song 365: "Walk On Water/Stan/Love The Way You Lie (SNL Medley)"
# Song 366: "Rap Battle (1994)"
# Song 367: "Public Service Announcement (SSLP)"
# Song 368: "’97 Blazer"
# Song 369: "Letter To Detroit"
# "Numb Encore (Remix)" is not valid. Skipping.
# Song 370: "Hip Hop"
# "Dude (Skit)" is not valid. Skipping.
# Song 371: "Phone Tap (Freestyle)"
# Song 372: "Fuck That Shit (Rapture)"
# Song 373: "Eminem Freestyle (Hollywood Homicide)"
# Song 374: "Role Model (Demo)"
# "Killer (Original)" is not valid. Skipping.
# Song 375: "Radio Freestyle 1"
# Song 376: "Ghost Stories"
# Song 377: "Pick It Up"
# "Brenda (Skit) (1998)" is not valid. Skipping.
# "Lose Yourself (Drum & Bass Remix)" is not valid. Skipping.
# Song 378: "Food Stamp (Phone Tap Freestyle)"
# Song 379: "Cut Back"
# Song 380: "Just Don’t Give a #?@! (Radio Edit)"
# "Zane Lowe BBC Radio Interview Part 2" is not valid. Skipping.
# "That’s How (Skit)" is not valid. Skipping.
# Song 381: "Murder Murder (Next Friday)"
# Song 382: "Guilty Conscience (Radio Extra Clean W/New Hook)"
# "Cleanin’ Out My Closet (Drum & Bass Remix)" is not valid. Skipping.
# Song 383: "Serious"
# Song 384: "Stuff To Never Rhyme (The Don’ts)"
# "Rock the Bells (Live at Howard Gilman Opera House)" is not valid. Skipping.
# "Cock Massage (Skit)" is not valid. Skipping.
# Song 385: "Beautiful (Radio Edit)"
# Song 386: "Unreleased Songs [Discography List]"
# Song 387: "MC Hammer vs. Vanilla Ice"
# Song 388: "I Kissed a Boy"
# Song 389: "Berzerk Explained"
# Song 390: "Brain Damage (Snippet)"
# "Infinite [Credits]" is not valid. Skipping.
# "Lose Yourself (Instrumental)" is not valid. Skipping.
# Song 391: "Radio Freestyle 2"
# Song 392: "Criminal (Snippet)"
# Song 393: "What Colour Is Soul"
# Song 394: "Hate Me Now Freestyle"
# Song 395: "Don’t Chew With Your Mouth Full"
# Song 396: "Role Model (Clean Version)"
# "Ariel (Skit)" is not valid. Skipping.
# Song 397: "Eminem, Paul Rosenberg Intro"
# Song 398: "C’mon Everybody"
# Song 399: "Guilty Conscience (Radio Version)"
# Song 400: "Radio Freestyle 3"
# Song 401: "Stolen Power"
# Song 402: "Mic Check One Two"
# Song 403: "If I Had (Radio Edit)"
# Song 404: "Open Mic Feb. 17, 1996"
# Song 405: "Verse 1"
# "When We Ride On Our Enemies (Remix)" is not valid. Skipping.
# "Dirty Steve (Skit)" is not valid. Skipping.
# Song 406: "Cancerous (Freestyle)"
# Song 407: "Starting To Look Like An M&M!"
# Song 408: "What Time You Sucking It*"
# Song 409: "Broke Day (Snippet of ”It’s Okay”)"
# "The Watcher(Remix)" is not valid. Skipping.
# Song 410: "Verse 3"
# Song 411: "Without Me (A Cappella)"
# Song 412: "DJ Fashion Freestyle"
# Song 413: "Eminem Music Videos"
# Song 414: "Just Don’t Give a Fuck (A Cappella)"
# "Benzino II (Skit)" is not valid. Skipping.
# Song 415: "The Slim Shady Show Freestyle"
# Song 416: "Guilty Conscience (A Cappella)"
# Song 417: "Ode To Detroit"
# Song 418: "Don’t Call Me Marshall (Intro)"
# Song 419: "Breaking News (Intro)"
# Song 420: "I Get Money"
# Song 421: "Freestyle (Attitude)"
# Song 422: "Second Chance"
# "Taj Mahal (Skit)" is not valid. Skipping.
# Song 423: "Rap Game (Solo Mix)"
# Song 424: "Wicked Shit Freestyle"
# Song 425: "Male Prostitute"
# Song 426: "The Kids (Unreleased Demo)"
# Song 427: "My Name Is (Snippet)"
# "What’s Your Intent? (Live)" is not valid. Skipping.
# Song 428: "Passin’ out concussions"
# Song 429: "Drop It Like It’s Hot Freestyle"
# Song 430: "Verse 2"
# "Man With Van (Skit)" is not valid. Skipping.
# "Nicole (Skit)" is not valid. Skipping.
# "Writer’s Block [DJ Premier Remix]" is not valid. Skipping.
# Song 431: "The Half-Time Show Freestyle"
# "Fat Beats (Skit)" is not valid. Skipping.
# Song 432: "Keys To The City"
# Song 433: "Canibus Impression Freestyle"
# "Record Store 1 (Skit)" is not valid. Skipping.
# Song 434: "Insult to Injury"
# "Fuck You (Lab Rat Remix)" is not valid. Skipping.
# "My Name Is (Instrumental)" is not valid. Skipping.
# Song 435: "Business (A Cappella)"
# Song 436: "I’m Shady (Snippet)"
# "Victory (Remix)" is not valid. Skipping.
# Song 437: "Bump Heads - DJ Green Lantern Version"
# Song 438: "Guilty Conscience (Snippet)"
# "Junko (Skit)" is not valid. Skipping.
# "Crack A Bottle (Shady Remix)" is not valid. Skipping.
# "Eminem (Skit)" is not valid. Skipping.
# "Rap Name (Remix)" is not valid. Skipping.
# Song 439: "Any Word Freestyle"
# "Without Me (Instrumental)" is not valid. Skipping.
# Song 440: "What’s Your Intent?"
# Song 441: "Mystical Diss"
# "Slut Phone Call (Skit)" is not valid. Skipping.
# "Curtis (Skit)" is not valid. Skipping.
# "Jesse (Skit)" is not valid. Skipping.
# Song 442: "Cut Back (Leak)"
# Song 443: "Jimmy Crack Corn (Cashis Vocal Mix (EX))"
# "Use This Gospel (Remix)" is not valid. Skipping.
# Song 444: "PhatBeats Prank Call"
# "Rex (Skit)" is not valid. Skipping.
# Song 445: "Mariah Carey Voicemail (Anger Management Tour 2005)"
# "She’s The One (Remix)" is not valid. Skipping.
# "Record Store 2 (Skit)" is not valid. Skipping.
# Song 446: "Slim Shady"
# Song 447: "Run Your Jewels (Snippet)"
# Song 448: "Medicine Man (Only Eminem)"
# Song 449: "Hot 100 Chart History"
# "Just Don’t Give a Fuck (Instrumental)" is not valid. Skipping.
# "Psychopath Killer Remix" is not valid. Skipping.
# "Sing for the Moment (Instrumental)" is not valid. Skipping.
# Song 450: "Mancow (Freestyle)"
# "Lose Yourself (Live at the 92nd Academy Awards)" is not valid. Skipping.
# Song 451: "Superman (Clean Radio Edit)"
# "We Did It (Skit)" is not valid. Skipping.
# Song 452: "The Real Slim Shady (Murda Mixtape Version)"
# Song 453: "Eminem Full Discography"
# "Guilty Conscience (Instrumental)" is not valid. Skipping.
# "From Olive Us to Olive U" is not valid. Skipping.
# Song 454: "The Kids (Demo)"
# Song 455: "Eminem - Get You Mad (Türkçe Çeviri)"
# Song 456: "Real Slim Shady (EDIT)"
# "Fight Music (Remix)" is not valid. Skipping.
# Song 457: "WJLB 1998 Promo"
# "Interview With Hot 97 (Disses Benzino)" is not valid. Skipping.
# "Cleanin’ Out My Closet (Instrumental)" is not valid. Skipping.
# Song 458: "Everything I Do"
# "The Real Slim Shady (Instrumental)" is not valid. Skipping.
# "Ric Flair Drip (Remix)" is not valid. Skipping.
# "The Heat" is not valid. Skipping.
# Song 459: "Cannon for nick"
# "Use This Gospel (Dre Mix)" is not valid. Skipping.
# Song 460: "Rap Game (Bump Heads)"
# Song 461: "Low, Down, Dirty (Unmastered Sequence version)"
# "Medicine Man (Remix)" is not valid. Skipping.
# "30 Minutes" is not valid. Skipping.
# "Revival [Credits]" is not valid. Skipping.
# Song 462: "The ‘N’ Bomb"
# "Lose Yourself (Live)" is not valid. Skipping.
# Song 463: "Whoo Kid Freestyle"
# "Rondell’s Beat Tape (Skit)" is not valid. Skipping.
# Song 464: "Rolling Stone Q/A Exclusive 2013"
# "The Way I Am (Instrumental)" is not valid. Skipping.
# "Stan (Instrumental)" is not valid. Skipping.
# "Dance On It" is not valid. Skipping.
# Song 465: "Rap God (Lyrics on Genius)"
# Song 466: "Anger Management (Turkish Translation)"
# "I’m Back/Kill You/Under the Influence (Live in California)" is not valid. Skipping.
# "Business (Kevin WiRE Remix)" is not valid. Skipping.
# Song 467: "Hit ’Em Up"
# Song 468: "Microphone (Studio Edit)"
# "#hot16challenge2" is not valid. Skipping.
# "Business - Live At The Palace of Auburn Hills, Detroit / 2002" is not valid. Skipping.
# "Mockingbird (Instrumental)" is not valid. Skipping.
# "Pop Smoke - Mood Swings (Remix) Ft Eminem, Lloyd Banks & Lil Tjay" is not valid. Skipping.
# "Its Murda (Remix)" is not valid. Skipping.
# Song 469: "Eminem - Zeus (ترجمه فارسی)"
# "8 Mile (Live in Dublin)" is not valid. Skipping.
# "24kgoldn - Mood (Remix) Ft Tupac & Eminem" is not valid. Skipping.
# "Intoxication" is not valid. Skipping.
# Song 470: "Basket Case Freestyle"
# "When I’m Gone (Instrumental)" is not valid. Skipping.
# "Mockingbird Remix" is not valid. Skipping.
# Song 471: "Premonition (PL)"
# "No Love (Remix)" is not valid. Skipping.
# Song 472: "We Made You (Digital Single Version)"
# "Dababy - Blind (Remix) Ft Eminem & XXXTENTACION" is not valid. Skipping.
# "Renegade [Jay-z Remix]" is not valid. Skipping.
# "Realnost (Lucky You Remix)" is not valid. Skipping.
# Song 473: "Still Number One"
# Song 474: "NOT KEYS TO THE CITY"
# Song 475: "The Storm (2017 BET Cypher Český překlad)"
# "The Story So Far (Mockingbird Remix)" is not valid. Skipping.
# Song 476: "I Like A Girl Freestyle"
# Song 477: "The Murderous Shady"
# "Same Song and Dance (Remix)" is not valid. Skipping.
# Song 478: "Ghost"
# Song 479: "Canopy Freestyle"
# "Call Me Back (Skit), Is it a Crime?" is not valid. Skipping.
# Song 480: "Eminem - Difficult (MAGYAR FORDÍTÁS)"
# Song 481: "My Πame is"
# "So Bad (Remix)" is not valid. Skipping.
# Song 482: "Bangkok Playmates"
# "Scary Movie (Sonorous Star Remix)" is not valid. Skipping.
# Song 483: "One Chance"
# Song 484: "Eminem - Lose yourself (Translation in Arabic)"
# "BBN Booda - Pablo remix - eminem & Juice wrld & Post malone & XXXTENTACION & Drake" is not valid. Skipping.
# Song 485: "I’m A Ghost"
# "Brenda (Skit)" is not valid. Skipping.
# Song 486: "Eminem - Hello (Türkçe Çeviri)"
# "The Eminem Interview" is not valid. Skipping.
# "All I Think About (Remix)" is not valid. Skipping.
# "In The End (Linkin Park, Mellen Gi & Tommee Profitt Remix)" is not valid. Skipping.
# "Stan, M. M. and the Bad Guy... (Remix)." is not valid. Skipping.
# "Lucky You (Remix)" is not valid. Skipping.
# "Fuck Obie (Skit)" is not valid. Skipping.
# Song 487: "The Wake Up Show Freestyle"
# Song 488: "Holy fucking shit..... *Punches drywall*"
# "Controvery (Skit)" is not valid. Skipping.
# Song 489: "Public Service Announcement 2013"
# "Kill Em’ All" is not valid. Skipping.
# Song 490: "It’s the real slim shady"
# Song 491: "Premonition (Intro) (Kurdish Subtitle)"
# Song 492: "Elen diss track"
# "The Kiss (Skit) German translation" is not valid. Skipping.
# Song 493: "Shinin (Unreleased)"
# "5 Star Generals (Instrumental)" is not valid. Skipping.
# "Ass Like That [slowed] remix" is not valid. Skipping.
# Done. Found 493 songs.

# %% [markdown]
# # 3. Save/load the Genius Artist object <a name="3-bullet"></a> <a href="#0-bullet"> <sup><sup><sup>^</sup></sup></sup></a>

# %% [markdown]
# Save/load the Artist object containing artist’s lyrics and metadata.

# %%
ARTIST_OBJECT_ALL_PATH = settings['ARTIST_OBJECT_ALL_PATH']
ARTIST_OBJECT_SONGS_PATH = settings['ARTIST_OBJECT_SONGS_PATH']

# %% [markdown]
# ## 3.1 Save the object <a name="31-bullet"></a>

# %% [markdown]
# ### a) all (songs, non-songs, etc. )

# %%
with open(ARTIST_OBJECT_ALL_PATH, 'wb') as handle:
    pickle.dump(artist_all, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### b) only songs

# %%
with open(ARTIST_OBJECT_SONGS_PATH, 'wb') as handle:
    pickle.dump(artist_songs, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## 3.2 Load the object <a name="32-bullet"></a>

# %% [markdown]
# ### a) all (songs, non-songs, etc.)

# %%
with open(ARTIST_OBJECT_ALL_PATH, 'rb') as handle:
    artist_all = pickle.load(handle)

# %% [markdown]
# ### b) only songs

# %%
with open(ARTIST_OBJECT_SONGS_PATH, 'rb') as handle:
    artist_songs = pickle.load(handle)

# %% [markdown]
# # 4. Convert to a Pandas DataFrame object <a name="4-bullet"></a> <a href="#0-bullet"> <sup><sup><sup>^</sup></sup></sup></a>

# %% [markdown]
# Collect only important information from the raw data and create a Pandas DataFrame object from it.

# %% [markdown]
# ### a) all (songs, non-songs, etc.)

# %%
dataset_all = []

songs = artist_all.to_dict()['songs']

for popularity, song in tqdm(enumerate(songs)):
    song_record = {}
    
    try:
        # 1. song id
        song_record['song_id'] = song['id']
        # 2. lyrics state
        song_record['state'] = song['lyrics_state']
        # 3. title
        song_record['title'] = song['title']
        # 4. artist
        song_record['artist'] = song['artist']
        # 5. featured with
        song_record['featured'] = [artist['name'] for artist in song['featured_artists']]
        # 6. song popularity
        song_record['popularity'] = popularity + 1
        # 7. album id
        song_album = song['album']
        song_record['album_id'] = song_album['id'] if song_album else None
        # 8. album name
        song_record['album_name'] = song_album['name'] if song_album else None
        # 9. song's release date
        song_record['release_date'] = song['release_date']
        # 10. lyrics
        song_record['lyrics'] = song['lyrics']
        # 11. Genius lyrics page
        song_record['url'] = song['url']

        # 12. comments - sorted by votes (only the top 50 most voted comments)
        song_comments = api.song_comments(song['id'], per_page=50, page=1)
        song_record['comments'] = [comment['body']['plain'] for comment in song_comments['comments']]
        # 13. comments total count
        song_record['comments_total_count'] = song_comments['total_count']
        
        # add to the dataset
        dataset_all.append(song_record) 
        
    except Exception as e:
        print(f"\nSong: {song['title']} (id:{song['id']})")
        print(e, '\n')
# Out:
# 586it [07:36,  1.28it/s]

# %%
eminem_all_df = pd.DataFrame(dataset_all)
eminem_all_df.head()
# Out:
#    song_id     state          title  artist      featured  popularity  \
# 0   235729  complete        Rap God  Eminem            []           1
# 1  3958196  complete       Killshot  Eminem            []           2
# 2  5180439  complete       Godzilla  Eminem  [Juice WRLD]           3
# 3      207  complete  Lose Yourself  Eminem            []           4
# 4   235732  complete    The Monster  Eminem     [Rihanna]           5
#
#    album_id                         album_name release_date  \
# 0  672689.0  The Marshall Mathers LP2 (Deluxe)   2013-10-14
# 1       NaN                               None   2018-09-14
# 2  594809.0            Music to Be Murdered By   2020-01-17
# 3  452012.0                        The Singles   2002-10-28
# 4  672689.0  The Marshall Mathers LP2 (Deluxe)   2013-10-29
#
#                                               lyrics  \
# 0  [Intro]\n"Look, I was gonna go easy on you not...
# 1  [Intro]\nYou sound like a bitch, bitch\nShut t...
# 2  [Intro]\nUgh, you're a monster\n\n[Verse 1: Em...
# 3  [Intro]\nLook, if you had one shot or one oppo...
# 4  [Intro: Rihanna]\nI'm friends with the monster...
#
#                                               url  \
# 0        https://genius.com/Eminem-rap-god-lyrics
# 1       https://genius.com/Eminem-killshot-lyrics
# 2       https://genius.com/Eminem-godzilla-lyrics
# 3  https://genius.com/Eminem-lose-yourself-lyrics
# 4    https://genius.com/Eminem-the-monster-lyrics
#
#                                             comments  comments_total_count
# 0  [It’s clear now to everyone who the King and t...                   459
# 1  [Eminem Sucks haha, GENIUS NOT EVEN READY LOL,...                  1252
# 2  [This definitely takes the spot of most unexpe...                   624
# 3  [This was Eminem at the top of the entire rap ...                   265
# 4  [Why do people hate that Eminem is different n...                   171

# %% [markdown]
# ### b) only songs

# %%
dataset_songs = []

songs = artist_songs.to_dict()['songs']

for popularity, song in tqdm(enumerate(songs)):
    song_record = {}
    
    try:
        # 1. song id
        song_record['song_id'] = song['id']
        # 2. lyrics state
        song_record['state'] = song['lyrics_state']
        # 3. title
        song_record['title'] = song['title']
        # 4. artist
        song_record['artist'] = song['artist']
        # 5. featured with
        song_record['featured'] = [artist['name'] for artist in song['featured_artists']]
        # 6. song popularity
        song_record['popularity'] = popularity + 1
        # 7. album id
        song_album = song['album']
        song_record['album_id'] = song_album['id'] if song_album else None
        # 8. album name
        song_record['album_name'] = song_album['name'] if song_album else None
        # 9. song's release date
        song_record['release_date'] = song['release_date']
        # 10. lyrics
        song_record['lyrics'] = song['lyrics']
        # 11. Genius lyrics page
        song_record['url'] = song['url']

        # 12. comments - sorted by votes (only the top 50 most voted comments)
        song_comments = api.song_comments(song['id'], per_page=50, page=1)
        song_record['comments'] = [comment['body']['plain'] for comment in song_comments['comments']]
        # 13. comments total count
        song_record['comments_total_count'] = song_comments['total_count']
        
        # add to the dataset
        dataset_songs.append(song_record) 
        
    except Exception as e:
        print(f"\nSong: {song['title']} (id:{song['id']})")
        print(e, '\n')
# Out:
# 457it [06:53,  1.25s/it]
# Song: WJLB 1998 Promo (id:2868227)
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 493it [07:20,  1.12it/s]

# %%
eminem_songs_df = pd.DataFrame(dataset_songs)
eminem_songs_df.head()
# Out:
#    song_id     state          title  artist      featured  popularity  \
# 0   235729  complete        Rap God  Eminem            []           1
# 1  3958196  complete       Killshot  Eminem            []           2
# 2  5180439  complete       Godzilla  Eminem  [Juice WRLD]           3
# 3      207  complete  Lose Yourself  Eminem            []           4
# 4   235732  complete    The Monster  Eminem     [Rihanna]           5
#
#    album_id                         album_name release_date  \
# 0  672689.0  The Marshall Mathers LP2 (Deluxe)   2013-10-14
# 1       NaN                               None   2018-09-14
# 2  594809.0            Music to Be Murdered By   2020-01-17
# 3  452012.0                        The Singles   2002-10-28
# 4  672689.0  The Marshall Mathers LP2 (Deluxe)   2013-10-29
#
#                                               lyrics  \
# 0  [Intro]\n"Look, I was gonna go easy on you not...
# 1  [Intro]\nYou sound like a bitch, bitch\nShut t...
# 2  [Intro]\nUgh, you're a monster\n\n[Verse 1: Em...
# 3  [Intro]\nLook, if you had one shot or one oppo...
# 4  [Intro: Rihanna]\nI'm friends with the monster...
#
#                                               url  \
# 0        https://genius.com/Eminem-rap-god-lyrics
# 1       https://genius.com/Eminem-killshot-lyrics
# 2       https://genius.com/Eminem-godzilla-lyrics
# 3  https://genius.com/Eminem-lose-yourself-lyrics
# 4    https://genius.com/Eminem-the-monster-lyrics
#
#                                             comments  comments_total_count
# 0  [It’s clear now to everyone who the King and t...                   459
# 1  [Eminem Sucks haha, GENIUS NOT EVEN READY LOL,...                  1252
# 2  [This definitely takes the spot of most unexpe...                   624
# 3  [This was Eminem at the top of the entire rap ...                   265
# 4  [Why do people hate that Eminem is different n...                   171

# %% [markdown]
# ## 4.1 Store the DataFrame object <a name="41-bullet"></a>

# %% [markdown]
# ### a) all (songs, non-songs, etc.)

# %%
EMINEM_DF_ALL_RAW_PATH = settings['EMINEM_DF_ALL_RAW_PATH']

with open(EMINEM_DF_ALL_RAW_PATH, 'wb') as handle:
    pickle.dump(eminem_all_df, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### b) only songs

# %%
EMINEM_DF_SONGS_RAW_PATH = settings['EMINEM_DF_SONGS_RAW_PATH']

with open(EMINEM_DF_SONGS_RAW_PATH, 'wb') as handle:
    pickle.dump(eminem_songs_df, handle, protocol=pickle.HIGHEST_PROTOCOL)
